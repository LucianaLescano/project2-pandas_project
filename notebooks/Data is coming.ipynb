# %%
# !kaggle datasets download -d teajay/global-shark-attacks
# Out:
# ...
# 100%|████████████████████████████████████████| 548k/548k [00:00<00:00, 1.30MB/s]
# 100%|████████████████████████████████████████| 548k/548k [00:00<00:00, 1.30MB/s]

# %%
# !tar -xzvf global-shark-attacks.zip
# Out:
# x attacks.csv

# %%
import pandas as pd

# %%
data = pd.read_csv("../data/attacks.csv",encoding='cp1252')

# %%
data
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../src/general_cleaning.py')

# %%
from general_cleaning import first_step

# %%
sharks_data = first_step(data)

# %%
sharks_data
# Out:
#              Date             Country Dead  \
# 0     25-Jun-2018                 USA    N
# 1     18-Jun-2018                 USA    N
# 2     09-Jun-2018                 USA    N
# 3     08-Jun-2018           AUSTRALIA    N
# 4     04-Jun-2018              MEXICO    N
# ...           ...                 ...  ...
# 6297  Before 1903           AUSTRALIA    Y
# 6298  Before 1903           AUSTRALIA    Y
# 6299    1900-1905                 USA    Y
# 6300    1883-1889              PANAMA    Y
# 6301    1845-1853  CEYLON (SRI LANKA)    Y
#
#                                      Source  \
# 0                          R. Collier, GSAF
# 1            K.McMurray, TrackingSharks.com
# 2            K.McMurray, TrackingSharks.com
# 3                            B. Myatt, GSAF
# 4                                 A .Kipper
# ...                                     ...
# 6297       H. Taunton; N. Bartlett,  p. 234
# 6298  H. Taunton; N. Bartlett,  pp. 233-234
# ...

# %%
sys.path.append('../src/general_cleaning.py')

# %%
from deads_cleaning import deads_wrong

# %%
deads_wrong(sharks_data.Dead)
# Out:
# "['2017']"

# %%
from deads_cleaning import deads_def

# %%
new_sharks_data = deads_def(sharks_data.Dead,sharks_data)

# %%
sharks_data.to_csv('../data/new_attacks.csv')
